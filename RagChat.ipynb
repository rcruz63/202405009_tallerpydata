# %% [markdown]
# # RAG Chat

# %%
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.schema import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores.chroma import Chroma
import os
import shutil

# %%
from dataclasses import dataclass
# Deprecated
# from langchain.chat_models import ChatOpenAI
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate

# %%
os.chdir("/Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata")

# %%
# !pip install openai #Mínimo
# !pip install ipyreact tiktoken numpy #Óptimo
# Out:
# Requirement already satisfied: openai in /opt/anaconda3/lib/python3.11/site-packages (1.27.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (0.26.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.10.12)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /opt/anaconda3/lib/python3.11/site-packages (from openai) (4.9.0)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: ipyreact in /opt/anaconda3/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: tiktoken in /opt/anaconda3/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: anywidget>=0.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipyreact) (0.9.10)
# Requirement already satisfied: ipywidgets>=7.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipyreact) (8.1.2)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: psygnal>=0.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from anywidget>=0.2.0->ipyreact) (0.11.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from anywidget>=0.2.0->ipyreact) (4.9.0)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->ipyreact) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->ipyreact) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->ipyreact) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.10 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->ipyreact) (4.0.10)
# Requirement already satisfied: jupyterlab-widgets~=3.0.10 in /opt/anaconda3/lib/python3.11/site-packages (from ipywidgets>=7.0.0->ipyreact) (3.0.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.2.5)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (0.2.2)
# Requirement already satisfied: six in /opt/anaconda3/lib/python3.11/site-packages (from asttokens->stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyreact) (1.16.0)

# %%
from tools import *

# %%
from dotenv import load_dotenv
import os

load_dotenv()
openai_api_key = os.getenv('OPENAI_API_KEY')

import openai
client = openai.OpenAI()

# %%
check_openai()
# Out:
# Todo está ok! :)
# True

# %%
# Configura tu clave de API de OpenAI
openai.api_key = openai_api_key

# %% [markdown]
# ### Prompt con RAG
#
# - Generación de respuestas basada en recuperación (RAG)
# - Ejemplo: chatbot de dudas sobre la Python standard library
#
# ```python
# def chatbot_rag(pregunta):
#     prompt = f"""
# Eres un chatbot experto en la biblioteca estándar de Python. Utiliza la siguiente base de conocimientos para responder a la pregunta del usuario:
#
# Base de conocimientos: {recupera_info_relevante(pregunta)}
#
# Usuario: {pregunta}
# """
#     respuesta = genera_texto(prompt)
#     return respuesta
# ```

# %%
CHROMA_PATH = "chroma"
DATA_PATH = "library"

# %%
def save_to_chroma(chunks: list[Document]):
    ## Clear out the database first.
    #if os.path.exists(CHROMA_PATH):
    #    print (os.path.abspath(CHROMA_PATH))
    #    shutil.rmtree(CHROMA_PATH)

    # Create a new DB from the documents.
    #db = Chroma.from_documents(
    #    chunks, OpenAIEmbeddings(), persist_directory=CHROMA_PATH
    #)
    ## No es necesario llamar a persist() aquí
    ## db.persist()
    #print(f"Saved {len(chunks)} chunks to {CHROMA_PATH}.")
    # Obtener la ruta absoluta del directorio CHROMA_PATH
    chroma_path = os.path.abspath(CHROMA_PATH)
    
    # Verificar si el directorio existe
    if os.path.exists(chroma_path):
        # Mostrar la ruta absoluta para depuración
        print(f"Ruta absoluta de CHROMA_PATH: {chroma_path}")
        
        # Eliminar el directorio y su contenido
        shutil.rmtree(chroma_path)
    
    # Crear el directorio CHROMA_PATH si no existe
    os.makedirs(chroma_path, exist_ok=True)

    # Crear una nueva DB a partir de los documentos
    db = Chroma.from_documents(
        chunks, OpenAIEmbeddings(), persist_directory=chroma_path
    )

    print(f"Guardado {len(chunks)} fragmentos en {chroma_path}.")

# %%
def split_text(documents: list[Document]):
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=300,
        chunk_overlap=100,
        length_function=len,
        add_start_index=True,
    )
    chunks = text_splitter.split_documents(documents)
    print(f"Split {len(documents)} documents into {len(chunks)} chunks.")

    document = chunks[10]
    print(document.page_content)
    print(document.metadata)

    return chunks

# %%
def load_documents():
    loader = DirectoryLoader(DATA_PATH, glob="*.rst")
    documents = loader.load()
    print (f"There are {len(documents)} documents to proccess")
    return documents

# %%
def generate_data_store():
    documents = load_documents()
    chunks = split_text(documents)
    save_to_chroma(chunks)

# %%
generate_data_store()
# Out:
# [WARNING] Reference not found for 'hacl\* project' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/hashlib.rst_chunk line 4 column 22
#
# [WARNING] Could not load include file ../includes/wasm-ios-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/venv.rst line 61 column 1
# [WARNING] Could not load include file /using/venv-create.inc at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/venv.rst line 66 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/urllib.request.rst line 34 column 1
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "p{0.3\\linewidth}"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 38
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "p{0.3\\linewidth}"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 38
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 8
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/codecs.rst_chunk line 1 column 8
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/threading.rst line 50 column 1
#
# [WARNING] Reference not found for 'Key "', 'e;', 'f', '>abc;', '(def', 'ghi)'] >>> s = shlex.shlex(text, posix=true, punctuation_chars=true) >>> s.whitespace_split = true >>> list(s) ['a', '&&', 'b', ';', 'c', '&&', 'd', '"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/shlex.rst_chunk line 12 column 41
#
# [WARNING] Reference not found for 'Key "'.join(map(repr, self)) + '>' ... >>> m = mylist('abc') >>> m.append(m) >>> m.append('x') >>> print(m) <'a'"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/reprlib.rst_chunk_chunk line 13 column 6
# [WARNING] Reference not found for 'Key "'c'"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/reprlib.rst_chunk_chunk line 13 column 14
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/smtplib.rst line 24 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/zoneinfo.rst line 34 column 1
#
# [WARNING] Reference not found for 'the popular geometric drawing tools introduced in logo <https://en.wikipedia.org/wiki/turtle_ (robot)>' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/turtle.rst line 24 column 11
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/turtle.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/turtle.rst_chunk line 1 column 8
#
# [WARNING] Could not load include file ../includes/wasm-ios-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/readline.rst line 29 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/xmlrpc.server.rst line 28 column 1
#
# [WARNING] Could not load include file ../includes/wasm-ios-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/subprocess.rst line 30 column 1
# [WARNING] Reference not found for 'side-by-side assembly' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/subprocess.rst_chunk_chunk line 4 column 65
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/inspect.rst_chunk_chunk_chunk line 1 column 4
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/xml.etree.elementtree.rst_chunk line 1 column 4
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/email.policy.rst_chunk_chunk_chunk line 1 column 4
# [WARNING] Reference not found for 'mangle_from' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/email.policy.rst_chunk_chunk line 1 column 13
# [WARNING] Reference not found for 'mangle_from' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/email.policy.rst_chunk_chunk line 1 column 13
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/tkinter.ttk.rst_chunk line 1 column 4
#
# [WARNING] Reference not found for 'add_alias' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 21
# [WARNING] Reference not found for 'add_value_alias' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 27
# [WARNING] Reference not found for 'name' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 12
# [WARNING] Reference not found for 'value' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 13
# [WARNING] Reference not found for 'order' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 13
# [WARNING] Reference not found for 'ignore' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 14
# [WARNING] Reference not found for 'generate_next_value' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 27
# [WARNING] Reference not found for 'generate_next_value' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 14 column 34
# [WARNING] Reference not found for 'missing' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 15
# [WARNING] Reference not found for 'numeric_repr' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/enum.rst_chunk_chunk line 1 column 15
#
# [WARNING] Could not load include file ../includes/wasm-ios-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/curses.rst line 26 column 1
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/io.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/io.rst_chunk line 1 column 8
#
# [WARNING] Reference not found for 'unicode technical standard #18' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/re.rst_chunk_chunk line 2 column 15
#
# [WARNING] Reference not found for 'ctrl' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/signal.rst_chunk line 1 column 65
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/http.server.rst line 27 column 1
#
# [WARNING] Reference not found for 'from' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mailbox.rst_chunk_chunk line 1 column 15
# [WARNING] Reference not found for 'time' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mailbox.rst_chunk_chunk line 1 column 22
# [WARNING] Reference not found for 'from' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mailbox.rst_chunk_chunk line 1 column 15
# [WARNING] Reference not found for 'time' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mailbox.rst_chunk_chunk line 1 column 22
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/selectors.rst line 43 column 1
#
# [WARNING] Reference not found for 'hkey' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/winreg.rst line 543 column 6
# [WARNING] Reference not found for 'hkey' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/winreg.rst line 543 column 6
#
# [WARNING] Reference not found for 'threadsafety' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/sqlite3.rst_chunk_chunk line 1 column 16
# [WARNING] Reference not found for 'sqlite_threadsafe' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/sqlite3.rst_chunk_chunk line 1 column 21
# [WARNING] Reference not found for 'loading an extension' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/sqlite3.rst_chunk_chunk_chunk line 4 column 44
# [WARNING] Reference not found for 'sqlite limit category' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/sqlite3.rst_chunk_chunk_chunk line 1 column 29
# [WARNING] Reference not found for 'sqlite limit category' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/sqlite3.rst_chunk_chunk_chunk line 1 column 29
# [WARNING] Reference not found for 'database cursor' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/sqlite3.rst_chunk line 1 column 52
# [WARNING] Reference not found for 'returning clauses' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/sqlite3.rst_chunk_chunk_chunk line 4 column 51
#
# [WARNING] Reference not found for 'unc paths' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/pathlib.rst_chunk line 2 column 41
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socketserver.rst line 15 column 1
#
# [WARNING] Reference not found for 'Key "= other"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/stdtypes.rst_chunk_chunk line 2 column 15
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/xmlrpc.client.rst line 37 column 1
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/xmlrpc.client.rst_chunk_chunk line 1 column 4
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mmap.rst line 11 column 1
# [WARNING] Reference not found for 'madv' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mmap.rst line 347 column 6
# [WARNING] Reference not found for 'map' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mmap.rst line 384 column 5
# [WARNING] Reference not found for 'madv' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mmap.rst line 347 column 6
# [WARNING] Reference not found for 'map' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/mmap.rst line 384 column 5
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/http.client.rst line 33 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/imaplib.rst line 31 column 1
#
# [WARNING] Reference not found for 'not' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/operator.rst_chunk line 1 column 5
# [WARNING] Reference not found for 'is' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/operator.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'and' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/operator.rst_chunk line 1 column 5
# [WARNING] Reference not found for 'or' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/operator.rst_chunk line 1 column 4
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/poplib.rst line 33 column 1
# [WARNING] Reference not found for 'pop3.pass' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/poplib.rst_chunk line 1 column 11
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/asyncio.rst line 75 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/concurrent.futures.rst line 24 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ftplib.rst line 26 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst line 38 column 1
# [WARNING] Reference not found for 'cert' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk line 1 column 42
# [WARNING] Reference not found for 'verify' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk line 1 column 44
# [WARNING] Reference not found for 'op' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk line 1 column 40
# [WARNING] Reference not found for 'alert_description' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk line 3 column 19
# [WARNING] Reference not found for 'alert_description' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk line 1 column 55
# [WARNING] Reference not found for 'ssl_error' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk line 1 column 47
# [WARNING] Reference not found for '3' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk_chunk_chunk line 1 column 13
# [WARNING] Reference not found for '1' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk_chunk_chunk_chunk line 1 column 8
# [WARNING] Reference not found for '2' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk_chunk_chunk_chunk line 1 column 8
# [WARNING] Reference not found for '3' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk_chunk_chunk_chunk line 1 column 22
# [WARNING] Reference not found for '1' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk_chunk_chunk_chunk line 1 column 8
# [WARNING] Reference not found for '2' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk_chunk_chunk_chunk line 1 column 8
# [WARNING] Reference not found for 'Key "op_no_sslv3"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ssl.rst_chunk_chunk line 5 column 29
#
# [WARNING] Reference not found for 'class' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/gettext.rst_chunk line 1 column 59
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst line 22 column 1
# [WARNING] Reference not found for 'af' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 1 column 8
# [WARNING] Reference not found for 'sock' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 1 column 19
# [WARNING] Reference not found for 'so' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'msg' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 3 column 5
# [WARNING] Reference not found for 'sol' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 4 column 5
# [WARNING] Reference not found for 'scm' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 5 column 5
# [WARNING] Reference not found for 'ipproto' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 6 column 9
# [WARNING] Reference not found for 'ipport' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 7 column 8
# [WARNING] Reference not found for 'inaddr' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 8 column 8
# [WARNING] Reference not found for 'ip' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 9 column 4
# [WARNING] Reference not found for 'ipv6' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 10 column 6
# [WARNING] Reference not found for 'eai' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 11 column 5
# [WARNING] Reference not found for 'ai' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 12 column 4
# [WARNING] Reference not found for 'ni' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 13 column 4
# [WARNING] Reference not found for 'tcp' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 14 column 5
# [WARNING] Reference not found for 'sol_can' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 3 column 9
# [WARNING] Reference not found for 'can' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 4 column 5
# [WARNING] Reference not found for 'can_bcm' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 2 column 9
# [WARNING] Reference not found for 'packet' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 3 column 8
# [WARNING] Reference not found for 'rds' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 4 column 5
# [WARNING] Reference not found for 'rcvall' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 4 column 8
# [WARNING] Reference not found for 'tipc' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 1 column 6
# [WARNING] Reference not found for 'alg' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/socket.rst_chunk line 3 column 5
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/getpass.rst line 17 column 1
#
# [WARNING] Could not load include file ../includes/wasm-ios-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/multiprocessing.rst line 13 column 1
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/logging.rst_chunk_chunk line 1 column 4
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/collections.abc.rst_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/collections.abc.rst_chunk line 1 column 8
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/locale.rst_chunk_chunk line 1 column 4
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/locale.rst_chunk_chunk line 1 column 8
#
# [WARNING] Reference not found for 'after' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/logging.config.rst line 589 column 32
#
# [WARNING] Reference not found for 'b_base' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 9
# [WARNING] Reference not found for 'b_needsfree' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 14
# [WARNING] Reference not found for 'fields' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 9
# [WARNING] Reference not found for 'pack' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 7
# [WARNING] Reference not found for 'align' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 8
# [WARNING] Reference not found for 'anonymous' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 12
# [WARNING] Reference not found for 'length' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 9
# [WARNING] Reference not found for 'type' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 7
# [WARNING] Reference not found for 'type' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ctypes.rst_chunk_chunk line 1 column 7
#
# [WARNING] Could not load include file ../includes/wasm-ios-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/dbm.rst line 24 column 1
#
# [WARNING] Reference not found for 'Key "l"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/warnings.rst_chunk line 1 column 4
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/compileall.rst line 19 column 1
# [WARNING] Reference not found for 'Key "checked-hash"' at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/compileall.rst_chunk line 1 column 45
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/select.rst line 27 column 1
#
# [WARNING] Could not load include file ../includes/wasm-ios-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/ensurepip.rst line 43 column 1
#
# [WARNING] Could not load include file ../includes/wasm-notavail.rst at /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/library/webbrowser.rst line 56 column 1
# There are 293 documents to proccess
# Split 293 documents into 22917 chunks.
# new_event_loop()
#
# Create and return a new event loop object.
#
# Note that the behaviour of get_event_loop, set_event_loop, and new_event_loop functions can be altered by setting a custom event loop policy <asyncio-policies>.
#
# Contents
#
# This documentation page contains the following sections:
# {'source': 'library/asyncio-eventloop.rst', 'start_index': 1793}
# Ruta absoluta de CHROMA_PATH: /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/chroma
# Guardado 22917 fragmentos en /Users/rcruz2/Library/CloudStorage/OneDrive-MAPFRE/Trabajo/Cloud/PyData/202405009_tallerpydata/chroma.

# %%
PROMPT_TEMPLATE = """
Eres un chatbot experto en la biblioteca estándar de Python. Utiliza la siguiente base de conocimientos para responder a la pregunta del usuario:

Base de conocimientos: {context}

---

Usuario: {question}
"""

# %%
# Haz tu pregunta
query_text = "What is the use of dataclass from dataclasses"

# %%
def chatbot_rag_model(pregunta):
    # Prepare the DB.
    embedding_function = OpenAIEmbeddings()
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

    results = db.similarity_search_with_relevance_scores(query_text, k=3)
    if len(results) == 0 or results[0][1] < 0.7:
        print(f"Unable to find matching results.")
        return

    context_text = "\n\n---\n\n".join([doc.page_content for doc, _score in results])
    prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
    prompt = prompt_template.format(context=context_text, question=pregunta)
    print(prompt)

    model = ChatOpenAI()
    response_text = model.invoke(prompt)

    sources = [doc.metadata.get("source", None) for doc, _score in results]
    formatted_response = f"Response: {response_text}\nSources: {sources}"
    print(formatted_response)

# %%
def genera_texto(prompt):
    # Llama a la API de OpenAI para generar un texto basado en el prompt proporcionado
    respuesta = client.completions.create(model="gpt-3.5-turbo-instruct",
        prompt=prompt,
        max_tokens=1000,  # Ajusta según sea necesario
        n=1,
        stop=None,
        temperature=0.7
    )
    return respuesta.choices[0].text.strip()

# %%
def chatbot_rag(pregunta):
    # Prepare the DB.
    embedding_function = OpenAIEmbeddings()
    db = Chroma(persist_directory=CHROMA_PATH, embedding_function=embedding_function)

    results = db.similarity_search_with_relevance_scores(query_text, k=3)
    if len(results) == 0 or results[0][1] < 0.7:
        print(f"Unable to find matching results.")
        return

    context_text = "\n\n---\n\n".join([doc.page_content for doc, _score in results])
    prompt_template = ChatPromptTemplate.from_template(PROMPT_TEMPLATE)
    prompt = prompt_template.format(context=context_text, question=pregunta)
    print(prompt)

    response_text = genera_texto(prompt)

    sources = [doc.metadata.get("source", None) for doc, _score in results]
    formatted_response = f"Response: {response_text}\nSources: {sources}"
    print(formatted_response)

# %%
chatbot_rag_model(query_text)
# Out:
# Human:
# Eres un chatbot experto en la biblioteca estándar de Python. Utiliza la siguiente base de conocimientos para responder a la pregunta del usuario:
#
# Base de conocimientos: If @dataclass is used just as a simple decorator with no
# parameters, it acts as if it has the default values documented in this
# signature. That is, these three uses of @dataclass are
# equivalent:
#
# The parameters to @dataclass are:
#
# ---
#
# This function is not strictly required, because any Python mechanism
# for creating a new class with !__annotations__ can then apply the @dataclass <dataclass>
# function to convert that class to a dataclass. This function is provided
# as a convenience. For example:
#
# Is equivalent to:
#
# ---
#
# The @dataclass decorator will add various "dunder"
# methods to the class, described below. If any of the added methods
# already exist in the class, the behavior depends on the parameter, as
# documented below. The decorator returns the same class that it is called
# on; no new class is created.
#
# ---
#
# Usuario: What is the use of dataclass from dataclasses
#
# Response: content='Dataclasses in Python provide a way to automatically generate special methods such as `__init__()`, `__repr__()`, `__eq__()`, `__hash__()`, and others for simple classes. By using the `@dataclass` decorator, you can easily create classes that are optimized for data manipulation and comparison. It reduces the boilerplate code needed for defining classes and makes your code more concise and readable.' response_metadata={'token_usage': {'completion_tokens': 83, 'prompt_tokens': 242, 'total_tokens': 325}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None} id='run-b635030c-7c28-46e2-8489-6f2c4fb28c01-0'
# Sources: ['library/dataclasses.rst', 'library/dataclasses.rst', 'library/dataclasses.rst']

# %%
chatbot_rag(query_text)
# Out:
# Human:
# Eres un chatbot experto en la biblioteca estándar de Python. Utiliza la siguiente base de conocimientos para responder a la pregunta del usuario:
#
# Base de conocimientos: If @dataclass is used just as a simple decorator with no
# parameters, it acts as if it has the default values documented in this
# signature. That is, these three uses of @dataclass are
# equivalent:
#
# The parameters to @dataclass are:
#
# ---
#
# This function is not strictly required, because any Python mechanism
# for creating a new class with !__annotations__ can then apply the @dataclass <dataclass>
# function to convert that class to a dataclass. This function is provided
# as a convenience. For example:
#
# Is equivalent to:
#
# ---
#
# The @dataclass decorator will add various "dunder"
# methods to the class, described below. If any of the added methods
# already exist in the class, the behavior depends on the parameter, as
# documented below. The decorator returns the same class that it is called
# on; no new class is created.
#
# ---
#
# Usuario: What is the use of dataclass from dataclasses
#
# Response: El uso de @dataclass en dataclasses es para crear clases de datos en Python de manera más sencilla y eficiente. Al utilizar @dataclass como decorador, se pueden especificar parámetros que añadirán métodos especiales a la clase, como __init__, __repr__, __eq__, entre otros. Además, si se utiliza @dataclass sin parámetros, actúa como si tuviera los valores predeterminados documentados en su firma. También se puede utilizar @dataclass como función para convertir una clase existente con __annotations__ en una clase de datos.
# Sources: ['library/dataclasses.rst', 'library/dataclasses.rst', 'library/dataclasses.rst']
